# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
res_data = np.loadtxt(r"C:\\Users\\BaughLaflamme\\Desktop\\Qblox Master Folder\\QBlox Tutorials\\QCM-RF\\mixer calibration data\\Nov 12 -13 2024\\Trace_0017.csv", delimiter=",")

# %%
hi = 200000000
lo = 0

freqs_0 = res_data[:,0][lo:hi]
dbm_0 = res_data[:,1][lo:hi]

# %%
fig, ax = plt.subplots(1, 1, figsize = (14, 6))
ax.grid(ls="--", alpha = 0.9)
ax.plot(freqs_0, dbm_0, alpha = 1.0)#, label = "Day 0")
ax.set_title("Mixer calibration of QCM-RF")
ax.set_xlabel("Frequency [Hz]")
ax.set_ylabel("Output [dBm]")
# ax.set_ylim([-90,5])
plt.show()
