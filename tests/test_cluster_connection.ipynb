# %% [markdown]
# # Test Connection
#
# This notebook is used to test the connection to the QBlox clusters.

# %%
import qblox_instruments

# %%
# !qblox-pnp list
# Out:
# No devices found

# %%
cluster_ip = ""
cluster_name = ""

# %%
cluster = qblox_instruments.Cluster(
    cluster_name,
    cluster_ip
)

# %%
cluster.reset()
print(cluster.get_system_state())
