# %%
# Imports
import time
import matplotlib.pyplot as plt
import pyvisa
import numpy as np
from __future__ import annotations 
from typing import TYPE_CHECKING, Callable
from qcodes.instrument import find_or_create_instrument
from qblox_instruments import Cluster, ClusterType
if TYPE_CHECKING:
    from qblox_instruments.qcodes_drivers.module import Module

import os 
from pathlib import Path
path = Path(os.getcwd())

# update base working directory to QBlox
if path.stem != 'QBlox-CSG':
    base_dir = path.parents[1]
    os.chdir(base_dir)
else:
    base_dir = path


import sys
sys.path.append(r"C:\Users\BaughLaflamme\Documents\GitHub\QBlox-CSG\Libraries\QbloxSequenceHelpers")
import sequence_helperV2 as sh
import benchmarking as bm

from qblox_instruments import SpiRack
import numpy as np
import time

from zhinst.toolkit import Session

D5A_ADDRESS_1 = 8 #First D5a module from the left
D5A_ADDRESS_2 = 7 #Second D5a moduel from the left

# %%
new_experiment = bm.QbloxExperiment()
# Out:
# {2: <Module: cluster0_module2 of Cluster: cluster0>, 4: <Module: cluster0_module4 of Cluster: cluster0>, 6: <Module: cluster0_module6 of Cluster: cluster0>}
# Status: OKAY, Flags: NONE, Slot flags: NONE
# Connected to: Qblox SPI Rack (serial:None, firmware:{'device': 'v1.6 - May 10 2019 - mt', 'driver': {'version': '0.15.0', 'build': '20/12/2024-16:46:05', 'hash': '5fc66717', 'dirty': False}}) in 0.00s

# %%
nums_steps = 100
resolution = int(10000)


new_experiment.run_2D_sweep(num_steps = nums_steps,
							outer_sweep_length = resolution*nums_steps, 
							fine_gate_voltage = 1,
							coarse_gate_voltage = 0.0,
							start_points = [-0.5, 0], 
							end_points = [0.5, 1], 
							acq_sequencer = 0,
							acquisition_name = f"bias_tee_time_{time}",
							resolution = resolution,
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)
# Out:
# -0.003866829506595017
# -0.0038738153395212506
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In\2D_sweep_NumSteps100_OuterSweepLength1000000_fineGateVol1_coarseGateVol0.0_startPoint[0, 0]_endPoint[0, 1]_resolution10000.png
# Status: OKAY, State: STOPPED, Info Flags: FORCED_STOP, Warning Flags: NONE, Error Flags: NONE, Log: []
# False
# False

# %% [markdown]
# ## Fine Gate Voltage from 1 V to 2 V

# %% [markdown]
# ### Pre-amp should be lower than

# %% [markdown]
# ####  coarse gate 1D sweep

# %%
for voltage in [0, 0.5, 1, 2]:
	print(f"Voltage is {voltage}")
	new_experiment.run_1D_trace(num_steps = 1000,
								length_per_point = 10000, 
								fine_gate_voltage = 0,
								coarse_gate_voltage = voltage,
								start_point = 0, 
								end_point = 2.5,  
								acq_sequencer = 0, 
								acquisition_name = "1D_fine_gate_sweep", 
								acquisition_delay = 0, 
								resolution = 10000, 
								repeats = 1, 
								save_path = r'C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo',
								plot = True)
# Out:
# Voltage is 0
# c:\Users\BaughLaflamme\anaconda3\envs\zh-test\lib\site-packages\qblox_instruments\native\spi_rack_modules\d5a_module.py:454: RuntimeWarning: invalid value encountered in double_scalars
#   dt = np.abs(val_begin - val) / self._ramp_rate / num_steps
# ['1D_fine_gate_sweep', 0, 10000000]
# -0.004474890083048364
# -0.004453737176355642
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo\1D_trace_NumSteps1000_LengthPerPoint10000_fineGateVol0_coarseGateVol0_startPoint0_endPoint2_5_resolution10000
# Voltage is 0.5
# ['1D_fine_gate_sweep', 0, 10000000]
# -0.0039250610649731316
# -0.004004640937957987
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo\1D_trace_NumSteps1000_LengthPerPoint10000_fineGateVol0_coarseGateVol0_5_startPoint0_endPoint2_5_resolution10000
# Voltage is 1
# ['1D_fine_gate_sweep', 0, 10000000]
# -0.004577821201758671
# -0.004652173913043478
# ...

# %% [markdown]
# ####  fine gate 1D sweep

# %%
for voltage in [0, 0.5, 1, 1.5, 2]:
	print(f"Voltage is {voltage}")
	new_experiment.run_1D_trace(num_steps = 500,
								length_per_point = 1000, 
								fine_gate_voltage = voltage,
								coarse_gate_voltage = 0,
								start_point = 0, 
								end_point = 1,  
								acq_sequencer = 0, 
								acquisition_name = "1D_fine_gate_sweep", 
								acquisition_delay = 0, 
								resolution = 1000, 
								repeats = 1, 
								save_path = r'C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo',
								plot = True)
# Out:
# Voltage is 0
# ['1D_fine_gate_sweep', 0, 500000]
# -0.005256961406936981
# -0.005264289203712751
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo\1D_trace_NumSteps500_LengthPerPoint1000_fineGateVol0_coarseGateVol0_startPoint0_endPoint1_resolution1000
# Voltage is 0.5
# ['1D_fine_gate_sweep', 0, 500000]
# -0.004610161211529067
# -0.004459697117733268
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo\1D_trace_NumSteps500_LengthPerPoint1000_fineGateVol0_5_coarseGateVol0_startPoint0_endPoint1_resolution1000
# Voltage is 1
# ['1D_fine_gate_sweep', 0, 500000]
# -0.004768441621885686
# -0.004812408402540303
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo\1D_trace_NumSteps500_LengthPerPoint1000_fineGateVol1_coarseGateVol0_startPoint0_endPoint1_resolution1000
# Voltage is 1.5
# ['1D_fine_gate_sweep', 0, 500000]
# -0.004671226184660478
# -0.004617489008304837
# ...

# %%
nums_steps = 100
resolution = int(25000)
new_experiment.run_2D_sweep(num_steps = nums_steps,
							outer_sweep_length = resolution*nums_steps, 
							fine_gate_voltage = 0,
							coarse_gate_voltage = 0,
							start_points = [0, 0], 
							end_points = [-1, 1], 
							acq_sequencer = 0,
							acquisition_name = f"bias_tee_time_{time}",
							resolution = resolution,
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)
# Out:
# -0.005784367366878359
# -0.0037939618954567662
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In\2D_sweep_NumSteps100_OuterSweepLength2500000_fineGateVol0_coarseGateVol0_startPoint[0, 0]_endPoint[1, 1]_resolution25000.png
# Status: OKAY, State: STOPPED, Info Flags: FORCED_STOP, Warning Flags: NONE, Error Flags: NONE, Log: []
# False
# False

# %%
nums_steps = 100
resolution = int(15000)
for voltage in np.linspace(0, 1, 10):
	new_experiment.run_2D_sweep(num_steps = nums_steps,
							outer_sweep_length = resolution*nums_steps, 
							fine_gate_voltage = 0,
							coarse_gate_voltage = voltage,
							start_points = [0, 0], 
							end_points = [1, 1], 
							acq_sequencer = 0,
							acquisition_name = f"bias_tee_time_{time}",
							resolution = resolution,
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)

# %%
nums_steps = 100
resolution = int(15000)
new_experiment.run_2D_sweep(num_steps = nums_steps,
							outer_sweep_length = resolution*nums_steps, 
							fine_gate_voltage = 0,
							coarse_gate_voltage = 1,
							start_points = [0, 0], 
							end_points = [1, 1], 
							acq_sequencer = 0,
							acquisition_name = f"bias_tee_time_{time}",
							resolution = resolution,
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)

# %%
for time in np.linspace(10000, 50000, 10):

	new_experiment.run_2D_sweep(num_steps = 100,
							outer_sweep_length = int(time)*100, 
							fine_gate_voltage = 1,
							coarse_gate_voltage = 2,
							start_points = [0, 0], 
							end_points = [1, 1], 
							acq_sequencer = 0,
							acquisition_name = f"bias_tee_time_{time}",
							resolution = int(time),
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)

# %%
for voltage in np.linspace(1, 2, 10):
	print(f"voltage is {voltage} V")
	new_experiment.run_2D_sweep(num_steps = 100,
						outer_sweep_length = int(20000)*100, 
						fine_gate_voltage = 0,
						coarse_gate_voltage = voltage,
						start_points = [0, 0], # fine gate, coarse gate
						end_points = [1, 1], 
						acq_sequencer = 0,
						acquisition_name = f"bias_tee_time_{int(time.time())}",
						resolution = int(20000),
						play_repeats = 1, 
						save_path = r'C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\inital voltage from 1 V to 2 V (coarse_gate_voltage)',
						plot = True)

# %%
new_experiment.run_1D_trace(num_steps = 500,
								length_per_point = 1000, 
								fine_gate_voltage = 0,
								coarse_gate_voltage = 3,
								start_point = 0, 
								end_point = 1,  
								acq_sequencer = 0, 
								acquisition_name = "1D_fine_gate_sweep", 
								acquisition_delay = 0, 
								resolution = 1000, 
								repeats = 1, 
								save_path = r'C:\Users\BaughLaflamme\Desktop\Lu and Rishabh\demo',
								plot = True)

# %%
new_experiment.run_2D_sweep(num_steps = 100,
						outer_sweep_length = int(30000)*100, 
						fine_gate_voltage = 0,
						coarse_gate_voltage = 0,
						start_points = [0, 0], # fine gate, coarse gate
						end_points = [-0.5, 2], 
						acq_sequencer = 0,
						acquisition_name = f"bias_tee_time_{int(time.time())}",
						resolution = int(30000),
						play_repeats = 1, 
						save_path = r'C:\Users\BaughLaflamme\Desktop\\Lu and Rishabh',
						plot = True)
# Out:
# -0.006367138902458883
# -0.004261048689138577
# ໒(⊙ᴗ⊙)७✎▤: Plot has been saved at C:\Users\BaughLaflamme\Desktop\\Lu and Rishabh\2D_sweep_NumSteps100_OuterSweepLength3000000_fineGateVol0_coarseGateVol0_startPoint[0, 0]_endPoint[0, 2]_resolution30000.png
# Status: OKAY, State: STOPPED, Info Flags: FORCED_STOP, Warning Flags: NONE, Error Flags: NONE, Log: []
# False
# False

# %%
new_experiment.calibration()

# %%
new_experiment.spirack_2D_sweep(num_steps = 100,
							time_per_point = 0.02, 
							start_points = [2, 0], 
							end_points = [3, 2], 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)
# Out:
# V_outter 2.10101318359375
# V_inner_set 0.242431640625
# V_inner_set 0.0
# V_inner_set 0.02020263671875
# V_inner_set 0.0404052734375
# V_inner_set 0.06060791015625
# V_inner_set 0.080810546875
# V_inner_set 0.10101318359375
# V_inner_set 0.1212158203125
# V_inner_set 0.14141845703125
# V_inner_set 0.16162109375
# V_inner_set 0.18182373046875
# V_inner_set 0.2020263671875
# V_inner_set 0.22222900390625
# V_inner_set 0.242431640625
# V_inner_set 0.2626190185546875
# V_inner_set 0.2828216552734375
# V_inner_set 0.3030242919921875
# V_inner_set 0.3232269287109375
# V_inner_set 0.3434295654296875
# V_inner_set 0.3636322021484375
# V_inner_set 0.3838348388671875
# V_inner_set 0.4040374755859375
# V_inner_set 0.4242401123046875
# V_inner_set 0.4444427490234375
# V_inner_set 0.4646453857421875
# V_inner_set 0.4848480224609375
# V_inner_set 0.5050506591796875
# V_inner_set 0.5252532958984375
# V_inner_set 0.5454559326171875
# V_inner_set 0.5656585693359375
# V_inner_set 0.5858612060546875
# ...

# %%
new_experiment.spirack_2D_sweep(num_steps = 100,
							time_per_point = 0.002, 
							start_points = [2, 0], 
							end_points = [3, 2], 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)

# %%
new_experiment.spirack_1D_trace(num_steps = 100,
							time_per_point = 0.02, 
							set_point = 2.5,
							start_point = 0, 
							end_point = 2.5, 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)
# Out:
# Setting initial voltage on DAC 1
# V_inner_set 0.0
# V_inner_set 0.0
# V_inner_set 0.0252532958984375
# V_inner_set 0.050506591796875
# V_inner_set 0.0757598876953125
# V_inner_set 0.10101318359375
# V_inner_set 0.1262664794921875
# V_inner_set 0.151519775390625
# V_inner_set 0.1767730712890625
# V_inner_set 0.2020263671875
# V_inner_set 0.2272796630859375
# V_inner_set 0.2525177001953125
# V_inner_set 0.27777099609375
# V_inner_set 0.3030242919921875
# V_inner_set 0.328277587890625
# V_inner_set 0.3535308837890625
# V_inner_set 0.3787841796875
# V_inner_set 0.4040374755859375
# V_inner_set 0.429290771484375
# V_inner_set 0.4545440673828125
# V_inner_set 0.47979736328125
# V_inner_set 0.5050506591796875
# V_inner_set 0.530303955078125
# V_inner_set 0.5555572509765625
# V_inner_set 0.580810546875
# V_inner_set 0.6060638427734375
# V_inner_set 0.631317138671875
# V_inner_set 0.6565704345703125
# V_inner_set 0.68182373046875
# V_inner_set 0.7070770263671875
# ...

# %%
for lengthpp in [10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000]:

	new_experiment.run_1D_trace(num_steps = 500,
								length_per_point = lengthpp, 
								fine_gate_voltage = 0,
								coarse_gate_voltage = 2,
								start_point = 0, 
								end_point = 1,  
								acq_sequencer = 0, 
								acquisition_name = "1D_fine_gate_sweep", 
								acquisition_delay = 0, 
								resolution = lengthpp, 
								repeats = 1, 
								save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
								plot = True)

# %%
for numsteps in [500, 1000, 1500, 2000, 2500, 3000, 4000, 4500, 5000]:

	new_experiment.run_1D_trace(num_steps = 500,
								length_per_point = 20000, 
								fine_gate_voltage = 0,
								coarse_gate_voltage = 3,
								start_point = 0, 
								end_point = 1,  
								acq_sequencer = 0, 
								acquisition_name = "1D_fine_gate_sweep", 
								acquisition_delay = 0, 
								resolution = 20000, 
								repeats = 1, 
								save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
								plot = True)

# %%
new_experiment.spirack_2D_sweep(num_steps = 100,
							time_per_point = 0.002, 
							start_points = [2, 0], 
							end_points = [3, 2], 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)
# Out:
# Setting initial voltage on DAC 1
# V_outter 2.0
# V_inner_set 0.0
# V_inner_set 0.0
# V_inner_set 0.02020263671875
# V_inner_set 0.0404052734375
# V_inner_set 0.06060791015625
# V_inner_set 0.080810546875
# V_inner_set 0.10101318359375
# V_inner_set 0.1212158203125
# V_inner_set 0.14141845703125
# V_inner_set 0.16162109375
# V_inner_set 0.18182373046875
# V_inner_set 0.2020263671875
# V_inner_set 0.22222900390625
# V_inner_set 0.242431640625
# V_inner_set 0.2626190185546875
# V_inner_set 0.2828216552734375
# V_inner_set 0.3030242919921875
# V_inner_set 0.3232269287109375
# V_inner_set 0.3434295654296875
# V_inner_set 0.3636322021484375
# V_inner_set 0.3838348388671875
# V_inner_set 0.4040374755859375
# V_inner_set 0.4242401123046875
# V_inner_set 0.4444427490234375
# V_inner_set 0.4646453857421875
# V_inner_set 0.4848480224609375
# V_inner_set 0.5050506591796875
# V_inner_set 0.5252532958984375
# V_inner_set 0.5454559326171875
# V_inner_set 0.5656585693359375
# ...

# %%
session = Session("192.168.60.246")

device = session.connect_device("DEV3901")

# %%
device.system.identify(True)

# %%
device.sigouts[0].on(0)
device.sigins[0].scaling(1.40000000)

daq_module = session.modules.daq

daq_module.triggernode('/dev3901/demods/0/sample.R')
daq_module.type(0)
daq_module.clearhistory(1)
daq_module.bandwidth(0.00000000)
daq_module.historylength(1000000000000000)
daq_module.save.directory(r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In')
daq_module.save.fileformat(1)

# %%
daq_module.endless(1)
daq_module.subscribe('/dev3901/demods/0/sample.R.avg')
""" daq_module.subscribe('/dev3901/demods/0/sample.Theta.avg')
daq_module.subscribe('/dev3901/demods/0/sample.X.avg')
daq_module.subscribe('/dev3901/demods/0/sample.Y.avg') """
daq_module.execute()

device.sigouts[0].on(1)
device.sigouts[0].amplitudes[1](0.05000000)
time.sleep(1)
device.sigouts[0].on(0)
time.sleep(1)

daq_module.finish()
daq_module.unsubscribe('*')

# %%
data = daq_module.save.save(1)

# %% [markdown]
# ## different freq

# %%
# Imports
import time
import matplotlib.pyplot as plt
import pyvisa
import numpy as np
from __future__ import annotations 
from typing import TYPE_CHECKING, Callable
from qcodes.instrument import find_or_create_instrument
from qblox_instruments import Cluster, ClusterType
if TYPE_CHECKING:
    from qblox_instruments.qcodes_drivers.module import Module

import os 
from pathlib import Path
path = Path(os.getcwd())

# update base working directory to QBlox
if path.stem != 'QBlox-CSG':
    base_dir = path.parents[1]
    os.chdir(base_dir)
else:
    base_dir = path


import sys
sys.path.append(r"C:\Users\BaughLaflamme\Documents\GitHub\QBlox-CSG\Libraries\QbloxSequenceHelpers")
import sequence_helperV2 as sh
import benchmarking as bm

from qblox_instruments import SpiRack
import numpy as np
import time

from zhinst.toolkit import Session

D5A_ADDRESS_1 = 8 #First D5a module from the left
D5A_ADDRESS_2 = 7 #Second D5a moduel from the left

# %%
new_experiment = bm.QbloxExperiment()

# %%
for freq in np.arange(1000, 40000 + 10000, 10000):
	print(f"Frequency is {freq} Hz")
	new_experiment.spirack_2D_sweep(num_steps = 100,
							time_per_point = 0.002, 
							start_points = [2, 0], 
							end_points = [3, 2], 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True,
							freq = freq)

# %%
for freq in [51000, 61000]:
	print(f"Frequency is {freq} Hz")
	new_experiment.spirack_2D_sweep(num_steps = 100,
							time_per_point = 0.002, 
							start_points = [2, 0], 
							end_points = [3, 2], 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True,
							freq = freq)

# %%
for freq in [71000, 81000, 91000, 100000]:
	print(f"Frequency is {freq} Hz")
	new_experiment.spirack_2D_sweep(num_steps = 100,
							time_per_point = 0.002, 
							start_points = [2, 0], 
							end_points = [3, 2], 
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True,
							freq = freq)

# %%
for time in np.linspace(10000, 50000, 10):

	new_experiment.run_2D_sweep(num_steps = 100,
							outer_sweep_length = int(time)*100, 
							fine_gate_voltage = 1,
							coarse_gate_voltage = 2,
							start_points = [0, 0], 
							end_points = [1, 1], 
							acq_sequencer = 0,
							acquisition_name = f"bias_tee_time_{time}",
							resolution = int(time),
                            play_repeats = 1, 
                            save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In',
							plot = True)

# %%
new_experiment.aquire_data(acq_sequencer=0, 
						   acquisition_name="test", 
						   acquisition_length=100, 
						   acquisition_path=["I1"], 
						   acquisition_delay = 0, 
						   resolution = 1, 
						   save_path = r'C:\Users\BaughLaflamme\Desktop\T16 Thermal ALD SET Room Temperature Test With Lock-In', 
						   plot = True)
